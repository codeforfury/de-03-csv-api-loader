# %% [markdown]
# ## Purpose
# This notebook is used for initial, exploratory investigation of the API data before writing the final, clean pipeline logic in `src/`.

# %%
# Import libraries
import requests
import pandas as pd

# %%
# Fetching URl
url = "https://date.nager.at/api/v3/PublicHolidays/2025/US"

# Storing the response of URL
response = requests.get(url)

# Converting the json format of the reponse into dataframe
df = pd.DataFrame(response.json())

# %%
df.head()
# Out:
#          date                    localName                         name  \
# 0  2025-01-01               New Year's Day               New Year's Day
# 1  2025-01-20  Martin Luther King, Jr. Day  Martin Luther King, Jr. Day
# 2  2025-02-12           Lincoln's Birthday           Lincoln's Birthday
# 3  2025-02-17        Washington's Birthday               Presidents Day
# 4  2025-04-18                  Good Friday                  Good Friday
#
#   countryCode  fixed  global  \
# 0          US  False    True
# 1          US  False    True
# 2          US  False   False
# 3          US  False    True
# 4          US  False   False
#
#                                             counties launchYear  \
# 0                                               None       None
# 1                                               None       None
# 2  [US-CA, US-CT, US-IL, US-IN, US-KY, US-MI, US-...       None
# 3                                               None       None
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         17 non-null     object
#  1   localName    17 non-null     object
#  2   name         17 non-null     object
#  3   countryCode  17 non-null     object
#  4   fixed        17 non-null     bool
#  5   global       17 non-null     bool
#  6   counties     6 non-null      object
#  7   launchYear   0 non-null      object
#  8   types        17 non-null     object
# dtypes: bool(2), object(7)
# memory usage: 1.1+ KB

# %%
df.isnull().sum()
# Out:
# date            0
# localName       0
# name            0
# countryCode     0
# fixed           0
# global          0
# counties       11
# launchYear     17
# types           0
# dtype: int64
